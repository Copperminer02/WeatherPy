# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from citipy import citipy
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 786

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        for i in city_weather['weather']:
            city_description=i["description"]
              
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),"Country": city_country,"Lat": city_lat,"Lng": city_lng,"Max Temp": city_max_temp,"Humidity": city_humidity,"Cloudiness": city_clouds,"Wind Speed": city_wind,"Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | perote
# Processing Record 3 of Set 1 | west lafayette
# Processing Record 4 of Set 1 | vao
# Processing Record 5 of Set 1 | alanya
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | mayo
# Processing Record 9 of Set 1 | carnarvon
# Processing Record 10 of Set 1 | noumea
# Processing Record 11 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 1 | norman wells
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | kangaatsiaq
# Processing Record 16 of Set 1 | pevek
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 21 of Set 1 | the valley
# Processing Record 22 of Set 1 | faanui
# Processing Record 23 of Set 1 | kalmunai
# Processing Record 24 of Set 1 | tilichiki
# Processing Record 25 of Set 1 | bengkulu
# Processing Record 26 of Set 1 | mahon
# Processing Record 27 of Set 1 | nova olimpia
# Processing Record 28 of Set 1 | awjilah
# Processing Record 29 of Set 1 | sibu
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 1 | isangel
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | ye
# City not found. Skipping...
# Processing Record 37 of Set 1 | leningradskiy
# Processing Record 38 of Set 1 | port blair
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | narsaq
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | east london
# Processing Record 43 of Set 1 | khandbari
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | great falls
# Processing Record 48 of Set 1 | tukrah
# Processing Record 49 of Set 1 | arsk
# Processing Record 50 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | balakhninskiy
# Processing Record 4 of Set 2 | kushmurun
# Processing Record 5 of Set 2 | hasaki
# Processing Record 6 of Set 2 | shingu
# Processing Record 7 of Set 2 | ribeira grande
# Processing Record 8 of Set 2 | katherine
# Processing Record 9 of Set 2 | angoche
# Processing Record 10 of Set 2 | tuatapere
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | rundu
# Processing Record 13 of Set 2 | rocha
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | xining
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 2 | guilin
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | somerset east
# Processing Record 21 of Set 2 | hvolsvollur
# Processing Record 22 of Set 2 | dingle
# Processing Record 23 of Set 2 | sebeta
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | esperance
# Processing Record 26 of Set 2 | george town
# Processing Record 27 of Set 2 | lavrentiya
# Processing Record 28 of Set 2 | port hedland
# Processing Record 29 of Set 2 | nongstoin
# Processing Record 30 of Set 2 | te anau
# Processing Record 31 of Set 2 | marienburg
# Processing Record 32 of Set 2 | henties bay
# Processing Record 33 of Set 2 | bandarbeyla
# Processing Record 34 of Set 2 | hobart
# Processing Record 35 of Set 2 | zhigansk
# Processing Record 36 of Set 2 | chimoio
# Processing Record 37 of Set 2 | pangody
# Processing Record 38 of Set 2 | de aar
# Processing Record 39 of Set 2 | bairiki
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | tuktoyaktuk
# Processing Record 42 of Set 2 | kishtwar
# Processing Record 43 of Set 2 | garden city
# Processing Record 44 of Set 2 | upernavik
# Processing Record 45 of Set 2 | quatre cocos
# Processing Record 46 of Set 2 | tasiilaq
# Processing Record 47 of Set 2 | morristown
# Processing Record 48 of Set 2 | pano aqil
# Processing Record 49 of Set 2 | prince albert
# Processing Record 50 of Set 2 | libertador general san martin
# Processing Record 1 of Set 3 | gizo
# Processing Record 2 of Set 3 | takhatpur
# Processing Record 3 of Set 3 | saldanha
# Processing Record 4 of Set 3 | provideniya
# Processing Record 5 of Set 3 | saskylakh
# Processing Record 6 of Set 3 | bambous virieux
# Processing Record 7 of Set 3 | medea
# Processing Record 8 of Set 3 | tabou
# Processing Record 9 of Set 3 | kavieng
# Processing Record 10 of Set 3 | dunedin
# Processing Record 11 of Set 3 | eden
# Processing Record 12 of Set 3 | bethel
# Processing Record 13 of Set 3 | praxedis guerrero
# Processing Record 14 of Set 3 | pisco
# Processing Record 15 of Set 3 | kununurra
# Processing Record 16 of Set 3 | key largo
# Processing Record 17 of Set 3 | qaanaaq
# Processing Record 18 of Set 3 | lokhvytsya
# Processing Record 19 of Set 3 | parana
# Processing Record 20 of Set 3 | kukurecani
# Processing Record 21 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 3 | pavda
# City not found. Skipping...
# Processing Record 23 of Set 3 | nome
# Processing Record 24 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 3 | fortuna
# Processing Record 26 of Set 3 | luangwa
# Processing Record 27 of Set 3 | barceloneta
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | port lincoln
# Processing Record 30 of Set 3 | fort-shevchenko
# Processing Record 31 of Set 3 | gisborne
# Processing Record 32 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | daoukro
# Processing Record 35 of Set 3 | zamora
# Processing Record 36 of Set 3 | tual
# Processing Record 37 of Set 3 | huejuquilla el alto
# Processing Record 38 of Set 3 | derzhavinsk
# Processing Record 39 of Set 3 | diego de almagro
# Processing Record 40 of Set 3 | tura
# Processing Record 41 of Set 3 | plettenberg bay
# Processing Record 42 of Set 3 | jubayl
# City not found. Skipping...
# Processing Record 43 of Set 3 | umiray
# Processing Record 44 of Set 3 | fukue
# Processing Record 45 of Set 3 | altay
# Processing Record 46 of Set 3 | kahului
# Processing Record 47 of Set 3 | mimongo
# Processing Record 48 of Set 3 | sibolga
# Processing Record 49 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 50 of Set 3 | iqaluit
# Processing Record 1 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 4 | port alfred
# Processing Record 3 of Set 4 | ponta do sol
# Processing Record 4 of Set 4 | kisanga
# Processing Record 5 of Set 4 | izmit
# Processing Record 6 of Set 4 | macamic
# Processing Record 7 of Set 4 | wajir
# Processing Record 8 of Set 4 | kewanee
# Processing Record 9 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 4 | morro bay
# Processing Record 11 of Set 4 | conakry
# Processing Record 12 of Set 4 | savannah bight
# Processing Record 13 of Set 4 | pierre
# Processing Record 14 of Set 4 | vanavara
# Processing Record 15 of Set 4 | camopi
# Processing Record 16 of Set 4 | sakakah
# Processing Record 17 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 4 | yulara
# Processing Record 19 of Set 4 | san cristobal
# Processing Record 20 of Set 4 | victoria point
# Processing Record 21 of Set 4 | faya
# Processing Record 22 of Set 4 | avarua
# Processing Record 23 of Set 4 | jiuquan
# Processing Record 24 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 4 | pilar
# Processing Record 26 of Set 4 | muros
# Processing Record 27 of Set 4 | ritchie
# Processing Record 28 of Set 4 | berezovyy
# Processing Record 29 of Set 4 | beckley
# Processing Record 30 of Set 4 | grand gaube
# Processing Record 31 of Set 4 | gravdal
# Processing Record 32 of Set 4 | kismayo
# Processing Record 33 of Set 4 | jizan
# Processing Record 34 of Set 4 | butaritari
# Processing Record 35 of Set 4 | guerrero negro
# Processing Record 36 of Set 4 | sao filipe
# Processing Record 37 of Set 4 | kavaratti
# Processing Record 38 of Set 4 | avera
# Processing Record 39 of Set 4 | riyadh
# Processing Record 40 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 4 | kruisfontein
# Processing Record 42 of Set 4 | cardston
# Processing Record 43 of Set 4 | natitingou
# Processing Record 44 of Set 4 | atar
# Processing Record 45 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 4 | ulaangom
# Processing Record 47 of Set 4 | mezen
# Processing Record 48 of Set 4 | sosnovskiy
# City not found. Skipping...
# Processing Record 49 of Set 4 | husavik
# Processing Record 50 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 1 of Set 5 | prata
# Processing Record 2 of Set 5 | verdun
# Processing Record 3 of Set 5 | siderno
# Processing Record 4 of Set 5 | tessalit
# Processing Record 5 of Set 5 | loralai
# Processing Record 6 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 5 | katsuura
# Processing Record 8 of Set 5 | znamenka
# Processing Record 9 of Set 5 | beibei
# Processing Record 10 of Set 5 | berlevag
# Processing Record 11 of Set 5 | yemtsa
# Processing Record 12 of Set 5 | ypsonas
# Processing Record 13 of Set 5 | lasa
# Processing Record 14 of Set 5 | umm lajj
# Processing Record 15 of Set 5 | naze
# Processing Record 16 of Set 5 | egvekinot
# Processing Record 17 of Set 5 | uige
# Processing Record 18 of Set 5 | nanortalik
# Processing Record 19 of Set 5 | mehamn
# Processing Record 20 of Set 5 | pemangkat
# Processing Record 21 of Set 5 | sungaipenuh
# Processing Record 22 of Set 5 | novochernorechenskiy
# Processing Record 23 of Set 5 | tiksi
# Processing Record 24 of Set 5 | gawler
# Processing Record 25 of Set 5 | zhangye
# Processing Record 26 of Set 5 | moree
# Processing Record 27 of Set 5 | wukari
# Processing Record 28 of Set 5 | luderitz
# Processing Record 29 of Set 5 | grindavik
# Processing Record 30 of Set 5 | klaksvik
# Processing Record 31 of Set 5 | teya
# Processing Record 32 of Set 5 | mukhtolovo
# Processing Record 33 of Set 5 | batagay
# Processing Record 34 of Set 5 | parkes
# Processing Record 35 of Set 5 | jalu
# Processing Record 36 of Set 5 | cabo san lucas
# Processing Record 37 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 5 | kajaani
# Processing Record 39 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 5 | kodiak
# Processing Record 41 of Set 5 | saint anthony
# Processing Record 42 of Set 5 | airai
# Processing Record 43 of Set 5 | sao joao da barra
# Processing Record 44 of Set 5 | aklavik
# Processing Record 45 of Set 5 | honningsvag
# Processing Record 46 of Set 5 | kudahuvadhoo
# Processing Record 47 of Set 5 | kawambwa
# Processing Record 48 of Set 5 | souillac
# Processing Record 49 of Set 5 | lompoc
# Processing Record 50 of Set 5 | san quintin
# Processing Record 1 of Set 6 | berdigestyakh
# Processing Record 2 of Set 6 | svetlogorsk
# Processing Record 3 of Set 6 | taldan
# Processing Record 4 of Set 6 | turukhansk
# Processing Record 5 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 6 of Set 6 | teahupoo
# Processing Record 7 of Set 6 | chuy
# Processing Record 8 of Set 6 | hilo
# Processing Record 9 of Set 6 | siverek
# Processing Record 10 of Set 6 | koslan
# Processing Record 11 of Set 6 | taoudenni
# Processing Record 12 of Set 6 | tecpan
# Processing Record 13 of Set 6 | hienghene
# Processing Record 14 of Set 6 | port moresby
# Processing Record 15 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 6 | meulaboh
# Processing Record 18 of Set 6 | wahlstedt
# Processing Record 19 of Set 6 | hendersonville
# Processing Record 20 of Set 6 | ilulissat
# Processing Record 21 of Set 6 | hargeysa
# Processing Record 22 of Set 6 | bathsheba
# Processing Record 23 of Set 6 | nuevo laredo
# Processing Record 24 of Set 6 | soavinandriana
# Processing Record 25 of Set 6 | nieuw amsterdam
# Processing Record 26 of Set 6 | peniche
# Processing Record 27 of Set 6 | khatanga
# Processing Record 28 of Set 6 | beloha
# Processing Record 29 of Set 6 | bafq
# Processing Record 30 of Set 6 | antofagasta
# Processing Record 31 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 6 | castelo branco
# Processing Record 33 of Set 6 | odweyne
# Processing Record 34 of Set 6 | lewisville
# Processing Record 35 of Set 6 | orlik
# Processing Record 36 of Set 6 | tiznit
# Processing Record 37 of Set 6 | ahumada
# City not found. Skipping...
# Processing Record 38 of Set 6 | mumford
# Processing Record 39 of Set 6 | tucuman
# Processing Record 40 of Set 6 | balabac
# Processing Record 41 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 6 | kota bahru
# Processing Record 43 of Set 6 | luena
# Processing Record 44 of Set 6 | trollhattan
# Processing Record 45 of Set 6 | banda aceh
# Processing Record 46 of Set 6 | joensuu
# Processing Record 47 of Set 6 | stromness
# Processing Record 48 of Set 6 | kropotkin
# Processing Record 49 of Set 6 | komsomolskiy
# Processing Record 50 of Set 6 | bosaso
# Processing Record 1 of Set 7 | pacific grove
# Processing Record 2 of Set 7 | marovoay
# Processing Record 3 of Set 7 | srednekolymsk
# Processing Record 4 of Set 7 | green river
# Processing Record 5 of Set 7 | saint george
# Processing Record 6 of Set 7 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 7 | hithadhoo
# Processing Record 9 of Set 7 | san patricio
# Processing Record 10 of Set 7 | sovetskaya gavan
# Processing Record 11 of Set 7 | sun valley
# Processing Record 12 of Set 7 | lubao
# Processing Record 13 of Set 7 | buique
# Processing Record 14 of Set 7 | kerema
# Processing Record 15 of Set 7 | batemans bay
# Processing Record 16 of Set 7 | lokosovo
# Processing Record 17 of Set 7 | alekseyevsk
# Processing Record 18 of Set 7 | tapes
# Processing Record 19 of Set 7 | atherton
# Processing Record 20 of Set 7 | mount gambier
# Processing Record 21 of Set 7 | naron
# Processing Record 22 of Set 7 | nago
# Processing Record 23 of Set 7 | kaitangata
# Processing Record 24 of Set 7 | mogadishu
# Processing Record 25 of Set 7 | la ronge
# Processing Record 26 of Set 7 | codrington
# Processing Record 27 of Set 7 | oakdale
# Processing Record 28 of Set 7 | sitka
# Processing Record 29 of Set 7 | scalea
# Processing Record 30 of Set 7 | pokaran
# Processing Record 31 of Set 7 | wildwood
# Processing Record 32 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 7 | burgdorf
# Processing Record 34 of Set 7 | padang
# Processing Record 35 of Set 7 | ulladulla
# Processing Record 36 of Set 7 | ponnani
# Processing Record 37 of Set 7 | cherskiy
# Processing Record 38 of Set 7 | quelimane
# Processing Record 39 of Set 7 | champerico
# Processing Record 40 of Set 7 | mahebourg
# Processing Record 41 of Set 7 | namibe
# Processing Record 42 of Set 7 | valley city
# Processing Record 43 of Set 7 | sola
# Processing Record 44 of Set 7 | mogapi
# Processing Record 45 of Set 7 | ambilobe
# Processing Record 46 of Set 7 | banjar
# Processing Record 47 of Set 7 | humberto de campos
# Processing Record 48 of Set 7 | pechenga
# Processing Record 49 of Set 7 | penzance
# Processing Record 50 of Set 7 | kachug
# Processing Record 1 of Set 8 | nhulunbuy
# Processing Record 2 of Set 8 | auki
# Processing Record 3 of Set 8 | sipe sipe
# Processing Record 4 of Set 8 | kiruna
# Processing Record 5 of Set 8 | adelanto
# Processing Record 6 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 8 | laguna
# Processing Record 8 of Set 8 | khandyga
# Processing Record 9 of Set 8 | maniwaki
# Processing Record 10 of Set 8 | elizabeth city
# Processing Record 11 of Set 8 | tezu
# Processing Record 12 of Set 8 | vilhena
# Processing Record 13 of Set 8 | ambagarh chauki
# Processing Record 14 of Set 8 | ketchikan
# Processing Record 15 of Set 8 | yuxia
# Processing Record 16 of Set 8 | shitkino
# Processing Record 17 of Set 8 | thompson
# Processing Record 18 of Set 8 | taltal
# Processing Record 19 of Set 8 | chambas
# Processing Record 20 of Set 8 | hervey bay
# Processing Record 21 of Set 8 | aykhal
# Processing Record 22 of Set 8 | port-gentil
# Processing Record 23 of Set 8 | nishihara
# Processing Record 24 of Set 8 | alugan
# Processing Record 25 of Set 8 | longyearbyen
# Processing Record 26 of Set 8 | chifeng
# Processing Record 27 of Set 8 | tsumeb
# Processing Record 28 of Set 8 | eureka
# Processing Record 29 of Set 8 | saint-philippe
# Processing Record 30 of Set 8 | mount isa
# Processing Record 31 of Set 8 | namatanai
# Processing Record 32 of Set 8 | vestmanna
# Processing Record 33 of Set 8 | troitsko-pechorsk
# Processing Record 34 of Set 8 | kozhevnikovo
# Processing Record 35 of Set 8 | cacu
# Processing Record 36 of Set 8 | qaqortoq
# Processing Record 37 of Set 8 | lander
# Processing Record 38 of Set 8 | brokopondo
# Processing Record 39 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 40 of Set 8 | pustoshka
# Processing Record 41 of Set 8 | mulege
# Processing Record 42 of Set 8 | abu dhabi
# Processing Record 43 of Set 8 | yarada
# Processing Record 44 of Set 8 | olafsvik
# Processing Record 45 of Set 8 | severo-kurilsk
# Processing Record 46 of Set 8 | itarema
# Processing Record 47 of Set 8 | ostrovnoy
# Processing Record 48 of Set 8 | torbay
# Processing Record 49 of Set 8 | chiredzi
# Processing Record 50 of Set 8 | pindiga
# Processing Record 1 of Set 9 | college
# Processing Record 2 of Set 9 | yumen
# Processing Record 3 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 4 of Set 9 | yertarskiy
# Processing Record 5 of Set 9 | koundara
# Processing Record 6 of Set 9 | touros
# Processing Record 7 of Set 9 | challans
# Processing Record 8 of Set 9 | luocheng
# Processing Record 9 of Set 9 | kolimvari
# City not found. Skipping...
# Processing Record 10 of Set 9 | talnakh
# Processing Record 11 of Set 9 | iberia
# Processing Record 12 of Set 9 | sur
# Processing Record 13 of Set 9 | fort nelson
# Processing Record 14 of Set 9 | acapulco
# Processing Record 15 of Set 9 | adrar
# Processing Record 16 of Set 9 | seara
# Processing Record 17 of Set 9 | hutchinson
# Processing Record 18 of Set 9 | skiros
# City not found. Skipping...
# Processing Record 19 of Set 9 | aitape
# Processing Record 20 of Set 9 | poum
# Processing Record 21 of Set 9 | margate
# Processing Record 22 of Set 9 | arona
# Processing Record 23 of Set 9 | gamba
# Processing Record 24 of Set 9 | luanda
# Processing Record 25 of Set 9 | vostok
# Processing Record 26 of Set 9 | mango
# Processing Record 27 of Set 9 | garowe
# Processing Record 28 of Set 9 | richards bay
# Processing Record 29 of Set 9 | flin flon
# Processing Record 30 of Set 9 | marang
# Processing Record 31 of Set 9 | vila
# Processing Record 32 of Set 9 | florianopolis
# Processing Record 33 of Set 9 | lagoa
# Processing Record 34 of Set 9 | sogdiondon
# City not found. Skipping...
# Processing Record 35 of Set 9 | magadan
# Processing Record 36 of Set 9 | gazanjyk
# Processing Record 37 of Set 9 | clyde river
# Processing Record 38 of Set 9 | kutum
# Processing Record 39 of Set 9 | dryden
# Processing Record 40 of Set 9 | broken hill
# Processing Record 41 of Set 9 | lodja
# Processing Record 42 of Set 9 | puerto colombia
# Processing Record 43 of Set 9 | caravelas
# Processing Record 44 of Set 9 | ekhabi
# Processing Record 45 of Set 9 | cueto
# Processing Record 46 of Set 9 | salisbury
# Processing Record 47 of Set 9 | burica
# City not found. Skipping...
# Processing Record 48 of Set 9 | victoria
# Processing Record 49 of Set 9 | paka
# Processing Record 50 of Set 9 | vikarabad
# Processing Record 1 of Set 10 | cam ranh
# Processing Record 2 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 3 of Set 10 | bowen
# Processing Record 4 of Set 10 | santa luzia
# Processing Record 5 of Set 10 | santa helena de goias
# Processing Record 6 of Set 10 | abha
# Processing Record 7 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 10 | klyuchi
# Processing Record 9 of Set 10 | stornoway
# Processing Record 10 of Set 10 | nyurba
# Processing Record 11 of Set 10 | rincon
# Processing Record 12 of Set 10 | kjollefjord
# Processing Record 13 of Set 10 | axim
# Processing Record 14 of Set 10 | verkhnyaya inta
# Processing Record 15 of Set 10 | husainabad
# Processing Record 16 of Set 10 | geraldton
# Processing Record 17 of Set 10 | manokwari
# Processing Record 18 of Set 10 | kawalu
# Processing Record 19 of Set 10 | honiara
# Processing Record 20 of Set 10 | victor harbor
# Processing Record 21 of Set 10 | najran
# Processing Record 22 of Set 10 | asasa
# Processing Record 23 of Set 10 | shahrud
# Processing Record 24 of Set 10 | nemuro
# Processing Record 25 of Set 10 | varhaug
# Processing Record 26 of Set 10 | signagi
# City not found. Skipping...
# Processing Record 27 of Set 10 | suba
# Processing Record 28 of Set 10 | carbonear
# Processing Record 29 of Set 10 | portland
# Processing Record 30 of Set 10 | maltahohe
# Processing Record 31 of Set 10 | moura
# Processing Record 32 of Set 10 | bone
# Processing Record 33 of Set 10 | rawson
# Processing Record 34 of Set 10 | kerrobert
# Processing Record 35 of Set 10 | changji
# Processing Record 36 of Set 10 | wagar
# Processing Record 37 of Set 10 | udachnyy
# Processing Record 38 of Set 10 | ayr
# Processing Record 39 of Set 10 | constitucion
# Processing Record 40 of Set 10 | cidreira
# Processing Record 41 of Set 10 | waipawa
# Processing Record 42 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 10 | shanghai
# Processing Record 44 of Set 10 | timra
# Processing Record 45 of Set 10 | mae sot
# Processing Record 46 of Set 10 | isla vista
# Processing Record 47 of Set 10 | gotsu
# Processing Record 48 of Set 10 | fairbanks
# Processing Record 49 of Set 10 | porlamar
# Processing Record 50 of Set 10 | andros town
# Processing Record 1 of Set 11 | sao jose da coroa grande
# Processing Record 2 of Set 11 | jacobina
# Processing Record 3 of Set 11 | baruun-urt
# Processing Record 4 of Set 11 | khorixas
# Processing Record 5 of Set 11 | mutis
# Processing Record 6 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 7 of Set 11 | zinder
# Processing Record 8 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 9 of Set 11 | mahanoro
# Processing Record 10 of Set 11 | abnub
# Processing Record 11 of Set 11 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 12 of Set 11 | praia
# Processing Record 13 of Set 11 | comodoro rivadavia
# Processing Record 14 of Set 11 | boueni
# Processing Record 15 of Set 11 | labuhan
# Processing Record 16 of Set 11 | alice springs
# Processing Record 17 of Set 11 | zharkent
# Processing Record 18 of Set 11 | marawi
# Processing Record 19 of Set 11 | alofi
# Processing Record 20 of Set 11 | samoded
# Processing Record 21 of Set 11 | samarai
# Processing Record 22 of Set 11 | hayden
# Processing Record 23 of Set 11 | lewistown
# Processing Record 24 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 11 | guaraciaba do norte
# Processing Record 26 of Set 11 | grand-santi
# Processing Record 27 of Set 11 | vila velha
# Processing Record 28 of Set 11 | vardo
# Processing Record 29 of Set 11 | hollins
# Processing Record 30 of Set 11 | sao miguel do araguaia
# Processing Record 31 of Set 11 | tarakan
# Processing Record 32 of Set 11 | haines junction
# Processing Record 33 of Set 11 | banepa
# Processing Record 34 of Set 11 | nouadhibou
# Processing Record 35 of Set 11 | tygda
# Processing Record 36 of Set 11 | maarsen
# City not found. Skipping...
# Processing Record 37 of Set 11 | sainte-maxime
# Processing Record 38 of Set 11 | matara
# Processing Record 39 of Set 11 | broome
# Processing Record 40 of Set 11 | otradnoye
# Processing Record 41 of Set 11 | bay roberts
# Processing Record 42 of Set 11 | belaya gora
# Processing Record 43 of Set 11 | ibra
# Processing Record 44 of Set 11 | coahuayana
# Processing Record 45 of Set 11 | karpathos
# Processing Record 46 of Set 11 | lakes entrance
# Processing Record 47 of Set 11 | linhares
# Processing Record 48 of Set 11 | pasni
# Processing Record 49 of Set 11 | paidha
# Processing Record 50 of Set 11 | vestmannaeyjar
# Processing Record 1 of Set 12 | cabra
# Processing Record 2 of Set 12 | jinji
# Processing Record 3 of Set 12 | seoul
# Processing Record 4 of Set 12 | oktyabrskiy
# Processing Record 5 of Set 12 | whyalla
# Processing Record 6 of Set 12 | tougue
# Processing Record 7 of Set 12 | ayan
# Processing Record 8 of Set 12 | takoradi
# Processing Record 9 of Set 12 | walvis bay
# Processing Record 10 of Set 12 | coihaique
# Processing Record 11 of Set 12 | belmonte
# Processing Record 12 of Set 12 | popondetta
# Processing Record 13 of Set 12 | shepsi
# Processing Record 14 of Set 12 | opuwo
# Processing Record 15 of Set 12 | cowra
# Processing Record 16 of Set 12 | kizhinga
# Processing Record 17 of Set 12 | butler
# Processing Record 18 of Set 12 | dali
# Processing Record 19 of Set 12 | bubaque
# Processing Record 20 of Set 12 | mackay
# Processing Record 21 of Set 12 | canavieiras
# Processing Record 22 of Set 12 | puerto escondido
# Processing Record 23 of Set 12 | okhotsk
# Processing Record 24 of Set 12 | saint-pierre
# Processing Record 25 of Set 12 | catuday
# Processing Record 26 of Set 12 | ust-koksa
# Processing Record 27 of Set 12 | karratha
# Processing Record 28 of Set 12 | zhifang
# Processing Record 29 of Set 12 | santo tomas
# Processing Record 30 of Set 12 | necochea
# Processing Record 31 of Set 12 | maceio
# Processing Record 32 of Set 12 | roblin
# Processing Record 33 of Set 12 | christchurch
# Processing Record 34 of Set 12 | mizdah
# Processing Record 35 of Set 12 | surt
# Processing Record 36 of Set 12 | yar-sale
# Processing Record 37 of Set 12 | kardamaina
# Processing Record 38 of Set 12 | lingao
# Processing Record 39 of Set 12 | ugoofaaru
# Processing Record 40 of Set 12 | thinadhoo
# Processing Record 41 of Set 12 | ancud
# Processing Record 42 of Set 12 | alpena
# Processing Record 43 of Set 12 | tenenkou
# Processing Record 44 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 45 of Set 12 | sucua
# Processing Record 46 of Set 12 | kendari
# Processing Record 47 of Set 12 | seydi
# Processing Record 48 of Set 12 | menongue
# Processing Record 49 of Set 12 | gravelbourg
# Processing Record 50 of Set 12 | cayeli
# Processing Record 1 of Set 13 | corralillo
# Processing Record 2 of Set 13 | kot radha kishan
# Processing Record 3 of Set 13 | srivardhan
# Processing Record 4 of Set 13 | tres lagoas
# Processing Record 5 of Set 13 | ukiah
# Processing Record 6 of Set 13 | porbandar
# Processing Record 7 of Set 13 | khash
# Processing Record 8 of Set 13 | sevnica
# Processing Record 9 of Set 13 | sao felix do xingu
# Processing Record 10 of Set 13 | iquitos
# Processing Record 11 of Set 13 | terekli-mekteb
# Processing Record 12 of Set 13 | renqiu
# Processing Record 13 of Set 13 | sabzevar
# Processing Record 14 of Set 13 | melchor de mencos
# Processing Record 15 of Set 13 | matagami
# Processing Record 16 of Set 13 | apt
# Processing Record 17 of Set 13 | humaita
# Processing Record 18 of Set 13 | araouane
# Processing Record 19 of Set 13 | poronaysk
# Processing Record 20 of Set 13 | isla mujeres
# Processing Record 21 of Set 13 | trat
# Processing Record 22 of Set 13 | aras
# Processing Record 23 of Set 13 | svobodnyy
# Processing Record 24 of Set 13 | debre tabor
# Processing Record 25 of Set 13 | kyabe
# Processing Record 26 of Set 13 | port hardy
# Processing Record 27 of Set 13 | hambantota
# Processing Record 28 of Set 13 | cervo
# Processing Record 29 of Set 13 | san luis obispo
# Processing Record 30 of Set 13 | mareeba
# Processing Record 31 of Set 13 | bafoulabe
# Processing Record 32 of Set 13 | uchiza
# Processing Record 33 of Set 13 | gossas
# Processing Record 34 of Set 13 | hastings
# Processing Record 35 of Set 13 | segezha
# Processing Record 36 of Set 13 | barra do garcas
# Processing Record 37 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 38 of Set 13 | whitehorse
# Processing Record 39 of Set 13 | bonavista
# Processing Record 40 of Set 13 | lima
# Processing Record 41 of Set 13 | oussouye
# Processing Record 42 of Set 13 | tongren
# Processing Record 43 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 13 | apodi
# Processing Record 45 of Set 13 | salalah
# Processing Record 46 of Set 13 | hakui
# Processing Record 47 of Set 13 | guayabetal
# Processing Record 48 of Set 13 | sumter
# Processing Record 49 of Set 13 | port macquarie
# Processing Record 50 of Set 13 | darasun
# Processing Record 1 of Set 14 | huarmey
# Processing Record 2 of Set 14 | birao
# Processing Record 3 of Set 14 | kijang
# Processing Record 4 of Set 14 | tera
# Processing Record 5 of Set 14 | igarka
# Processing Record 6 of Set 14 | hay river
# Processing Record 7 of Set 14 | san carlos de bariloche
# Processing Record 8 of Set 14 | jawhar
# Processing Record 9 of Set 14 | anadyr
# Processing Record 10 of Set 14 | nivala
# Processing Record 11 of Set 14 | ossora
# Processing Record 12 of Set 14 | carman
# Processing Record 13 of Set 14 | mitsamiouli
# Processing Record 14 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 14 | luyang
# Processing Record 16 of Set 14 | dickinson
# Processing Record 17 of Set 14 | kamyaran
# Processing Record 18 of Set 14 | havoysund
# Processing Record 19 of Set 14 | fairlie
# Processing Record 20 of Set 14 | buraydah
# Processing Record 21 of Set 14 | hovd
# Processing Record 22 of Set 14 | jacksonville
# Processing Record 23 of Set 14 | waldshut-tiengen
# Processing Record 24 of Set 14 | santa cruz de la palma
# Processing Record 25 of Set 14 | otukpo
# Processing Record 26 of Set 14 | coquimbo
# Processing Record 27 of Set 14 | izberbash
# Processing Record 28 of Set 14 | hammerfest
# Processing Record 29 of Set 14 | jumla
# Processing Record 30 of Set 14 | meadow lake
# Processing Record 31 of Set 14 | socorro
# Processing Record 32 of Set 14 | sarkand
# Processing Record 33 of Set 14 | nizhniy tsasuchey
# Processing Record 34 of Set 14 | inyonga
# Processing Record 35 of Set 14 | amalapuram
# Processing Record 36 of Set 14 | callaguip
# Processing Record 37 of Set 14 | bucinisu
# Processing Record 38 of Set 14 | saint-joseph
# Processing Record 39 of Set 14 | magistralnyy
# Processing Record 40 of Set 14 | batiano
# Processing Record 41 of Set 14 | pekan nenas
# Processing Record 42 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 14 | hobyo
# Processing Record 44 of Set 14 | atmakur
# Processing Record 45 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 14 | jacareacanga
# Processing Record 47 of Set 14 | nabire
# Processing Record 48 of Set 14 | burgeo
# Processing Record 49 of Set 14 | spydeberg
# Processing Record 50 of Set 14 | nizhniy kuranakh
# Processing Record 1 of Set 15 | gondanglegi
# Processing Record 2 of Set 15 | pundaguitan
# Processing Record 3 of Set 15 | nizhnyaya salda
# Processing Record 4 of Set 15 | shakiso
# Processing Record 5 of Set 15 | balestrand
# Processing Record 6 of Set 15 | araguacu
# Processing Record 7 of Set 15 | melbu
# Processing Record 8 of Set 15 | riorges
# Processing Record 9 of Set 15 | beringovskiy
# Processing Record 10 of Set 15 | tartagal
# Processing Record 11 of Set 15 | san policarpo
# Processing Record 12 of Set 15 | mecca
# Processing Record 13 of Set 15 | cayenne
# Processing Record 14 of Set 15 | norsup
# Processing Record 15 of Set 15 | susurluk
# Processing Record 16 of Set 15 | flinders
# Processing Record 17 of Set 15 | bastia
# Processing Record 18 of Set 15 | valdosta
# Processing Record 19 of Set 15 | nalut
# Processing Record 20 of Set 15 | novo aripuana
# Processing Record 21 of Set 15 | maniitsoq
# Processing Record 22 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 15 | nauta
# Processing Record 24 of Set 15 | pokhara
# Processing Record 25 of Set 15 | gushikawa
# Processing Record 26 of Set 15 | asau
# Processing Record 27 of Set 15 | shush
# Processing Record 28 of Set 15 | ahipara
# Processing Record 29 of Set 15 | ternate
# Processing Record 30 of Set 15 | carutapera
# Processing Record 31 of Set 15 | kadoma
# Processing Record 32 of Set 15 | itoman
# Processing Record 33 of Set 15 | carlsbad
# Processing Record 34 of Set 15 | pangnirtung
# Processing Record 35 of Set 15 | pringsewu
# Processing Record 36 of Set 15 | kolpashevo
# Processing Record 37 of Set 15 | miraflores
# Processing Record 38 of Set 15 | mlalo
# Processing Record 39 of Set 15 | la crosse
# Processing Record 40 of Set 15 | chilca
# Processing Record 41 of Set 15 | simav
# Processing Record 42 of Set 15 | neftekamsk
# Processing Record 43 of Set 15 | nautla
# Processing Record 44 of Set 15 | oranjestad
# Processing Record 45 of Set 15 | vanimo
# Processing Record 46 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 47 of Set 15 | filadelfia
# Processing Record 48 of Set 15 | kraskino
# Processing Record 49 of Set 15 | mana
# Processing Record 50 of Set 15 | libreville
# Processing Record 1 of Set 16 | gambo
# Processing Record 2 of Set 16 | santa cruz cabralia
# Processing Record 3 of Set 16 | kinablangan
# Processing Record 4 of Set 16 | ayaviri
# Processing Record 5 of Set 16 | westpunt
# City not found. Skipping...
# Processing Record 6 of Set 16 | heinola
# Processing Record 7 of Set 16 | buchanan
# Processing Record 8 of Set 16 | pop
# Processing Record 9 of Set 16 | pontian kecil
# Processing Record 10 of Set 16 | los llanos de aridane
# Processing Record 11 of Set 16 | blacksburg
# Processing Record 12 of Set 16 | sandy bay
# Processing Record 13 of Set 16 | sinj
# Processing Record 14 of Set 16 | nicoya
# Processing Record 15 of Set 16 | beroroha
# Processing Record 16 of Set 16 | skibbereen
# Processing Record 17 of Set 16 | tarata
# Processing Record 18 of Set 16 | macusani
# Processing Record 19 of Set 16 | salekhard
# Processing Record 20 of Set 16 | fray bentos
# Processing Record 21 of Set 16 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 16 | pecos
# Processing Record 23 of Set 16 | misratah
# Processing Record 24 of Set 16 | raurkela
# City not found. Skipping...
# Processing Record 25 of Set 16 | moorhead
# Processing Record 26 of Set 16 | palora
# Processing Record 27 of Set 16 | nerchinskiy zavod
# Processing Record 28 of Set 16 | mount darwin
# Processing Record 29 of Set 16 | saucillo
# Processing Record 30 of Set 16 | worland
# Processing Record 31 of Set 16 | nuuk
# Processing Record 32 of Set 16 | bielsk podlaski
# Processing Record 33 of Set 16 | ushtobe
# Processing Record 34 of Set 16 | russell
# Processing Record 35 of Set 16 | kampene
# Processing Record 36 of Set 16 | kaeo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 728

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weather_data_df = pd.DataFrame(city_data)
weather_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Georgetown      MY   5.4112  100.3354     83.89        75          20
# 1          Perote      MX  19.5667  -97.2333     46.67        89         100
# 2  West Lafayette      US  40.4259  -86.9081     22.10        71         100
# 3             Vao      NC -22.6667  167.4833     77.92        84          74
# 4          Alanya      TR  36.5438   31.9998     51.93        77         100
# 5         Ushuaia      AR -54.8000  -68.3000     51.46        76          75
# 6          Barrow      US  71.2906 -156.7887    -11.18        70          75
# 7            Mayo      US  38.8876  -76.5119     24.17        57           0
# 8       Carnarvon      AU -24.8667  113.6333     87.87        35          15
# 9          Noumea      NC -22.2763  166.4572     80.01        99          34
#
#    Wind Speed Current Description
# 0        3.00          few clouds
# 1        3.78     overcast clouds
# 2        9.22     overcast clouds
# 3        4.36       broken clouds
# 4       25.10     overcast clouds
# 5       14.97       broken clouds
# 6       20.71                haze
# 7        7.00           clear sky
# 8       17.27          few clouds
# 9        3.20    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label="City_ID")
